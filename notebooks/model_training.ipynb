# %%
# Load dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install scikit-learn==1.8.0
# Out:
# Collecting scikit-learn==1.8.0
#   Downloading scikit_learn-1.8.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.24.1 in /usr/local/lib/python3.12/dist-packages (from scikit-learn==1.8.0) (2.0.2)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn==1.8.0) (1.16.3)
# Requirement already satisfied: joblib>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn==1.8.0) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn==1.8.0) (3.6.0)
# Downloading scikit_learn-1.8.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 77.9 MB/s eta 0:00:00
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
# Successfully installed scikit-learn-1.8.0

# %%
# !python "/content/drive/MyDrive/Colab Notebooks/AI PROJECT/src/model_a_train.py"
# Out:
# ============================================================
#   MODEL A - Answer Verifier Training
# ============================================================
#
# >>> Loading training data...
#
# >>> Expanding training set to verification pairs (Full dataset)...
#   Expanded to 351,464 examples  |  features: 5,000
#   Class balance - correct: 87,866  wrong: 263,598
#
# >>> Expanding dev set...
#   Expanded to 351,464 examples  |  features: 5,000
#   Class balance - correct: 87,866  wrong: 263,598
#
# [1/4] Training Logistic Regression...
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:1184: FutureWarning: 'n_jobs' has no effect since 1.8 and will be removed in 1.10. You provided 'n_jobs=-1', please leave it unspecified.
#   warnings.warn(msg, category=FutureWarning)
#   Trained in 5.3s
#
# [2/4] Training SVM (LinearSVC + Calibration)...
#   Trained in 61.0s
#
# [3/4] Training Bernoulli Naive Bayes...
#   Trained in 0.4s
#
# >>> Evaluating on dev set...
#
# ==================================================
#   Logistic Regression
# ==================================================
#   Accuracy  : 0.5132  (51.32%)
#   Macro F1  : 0.4786
#               precision    recall  f1-score   support
#
#        Wrong       0.76      0.51      0.61    263598
#      Correct       0.26      0.51      0.34     87866
#
#     accuracy                           0.51    351464
#    macro avg       0.51      0.51      0.48    351464
# weighted avg       0.63      0.51      0.55    351464
#
#   Confusion matrix saved → /content/drive/MyDrive/Colab Notebooks/AI PROJECT/notebooks/plots/cm_logistic_regression.png
#
# ==================================================
#   SVM (LinearSVC)
# ==================================================
#   Accuracy  : 0.7500  (75.00%)
#   Macro F1  : 0.4286
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
#               precision    recall  f1-score   support
#
#        Wrong       0.75      1.00      0.86    263598
#      Correct       0.00      0.00      0.00     87866
#
#     accuracy                           0.75    351464
#    macro avg       0.38      0.50      0.43    351464
# weighted avg       0.56      0.75      0.64    351464
#
#   Confusion matrix saved → /content/drive/MyDrive/Colab Notebooks/AI PROJECT/notebooks/plots/cm_svm_(linearsvc).png
#
# ==================================================
#   Bernoulli Naive Bayes
# ==================================================
#   Accuracy  : 0.7500  (75.00%)
#   Macro F1  : 0.4286
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
#               precision    recall  f1-score   support
#
#        Wrong       0.75      1.00      0.86    263598
#      Correct       0.00      0.00      0.00     87866
#
#     accuracy                           0.75    351464
#    macro avg       0.38      0.50      0.43    351464
# weighted avg       0.56      0.75      0.64    351464
#
#   Confusion matrix saved → /content/drive/MyDrive/Colab Notebooks/AI PROJECT/notebooks/plots/cm_bernoulli_naive_bayes.png
#
# >>> Running K-Means Clustering (Unsupervised)...
#
# [4/4] Training K-Means Clustering (Unsupervised)...
#   Subsampling 20,000 examples for K-Means (memory efficient)...
#   Trained in 27.5s
#
#   Silhouette Score : 0.0128  (range: -1 to 1, higher is better)
#   Cluster 0: 14,916 samples  |  purity=0.750  |  mostly WRONG answers
#   Cluster 1: 5,084 samples  |  purity=0.755  |  mostly WRONG answers
#
# [5/4] Training Label Propagation (Semi-Supervised)...
#   Trained in 3.4s
#   Label Propagation Accuracy : 0.7241
#   Label Propagation Macro F1 : 0.4235
#
# [ENSEMBLE] Building Soft-Vote Ensemble (LR + SVM + NB)...
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:1184: FutureWarning: 'n_jobs' has no effect since 1.8 and will be removed in 1.10. You provided 'n_jobs=-1', please leave it unspecified.
#   warnings.warn(msg, category=FutureWarning)
#   Ensemble built in 63.8s
#
# ==================================================
#   Soft-Vote Ensemble
# ==================================================
#   Accuracy  : 0.7500  (75.00%)
#   Macro F1  : 0.4286
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
#               precision    recall  f1-score   support
#
#        Wrong       0.75      1.00      0.86    263598
#      Correct       0.00      0.00      0.00     87866
#
#     accuracy                           0.75    351464
#    macro avg       0.38      0.50      0.43    351464
# weighted avg       0.56      0.75      0.64    351464
#
#   Confusion matrix saved → /content/drive/MyDrive/Colab Notebooks/AI PROJECT/notebooks/plots/cm_soft-vote_ensemble.png
#
# ════════════════════════════════════════════════════════════
#   FINAL COMPARISON TABLE
# ════════════════════════════════════════════════════════════
#                 model accuracy macro_f1
#   Logistic Regression   0.5132   0.4786
#       SVM (LinearSVC)   0.7500   0.4286
# Bernoulli Naive Bayes   0.7500   0.4286
#    Soft-Vote Ensemble   0.7500   0.4286
#
#   K-Means Silhouette Score : 0.0128
#
# >>> Saving models to /content/drive/MyDrive/Colab Notebooks/AI PROJECT/models/model_a/traditional/
# All models saved successfully!
# Comparison chart saved!
#
# ✅ Model A training complete!
