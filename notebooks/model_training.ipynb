# %%
# Load dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install scikit-learn==1.8.0
# !pip install nltk rouge-score
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 92.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24934 sha256=a28869e34eea0e081d22a53f0f509c7e8b170ac247e9f8c7a963f7bd487c0c79
#   Stored in directory: /root/.cache/pip/wheels/85/9d/af/01feefbe7d55ef5468796f0c68225b6788e85d9d0a281e7a70
# Successfully built rouge-score
# ...

# %%
# !python "/content/drive/MyDrive/Colab Notebooks/AI PROJECT/src/model_a_train.py"
# Out:
# [INFO] NLTK + rouge-score loaded — NLP metrics enabled.
# ...
#   MODEL A - Answer Verifier Training  (IMPROVED)
# ...
#
# >>> Loading training data...
#
# >>> Expanding training set (Full dataset) with OHE + hand-crafted features...
#   Expanded to 351,464 examples  |  features: 5,007
#   (OHE: 5,000  +  hand-crafted: 7)
#   Class balance - correct: 87,866  wrong: 263,598
#
# >>> Expanding dev set...
#   Expanded to 351,464 examples  |  features: 5,007
#   (OHE: 5,000  +  hand-crafted: 7)
#   Class balance - correct: 87,866  wrong: 263,598
#
# [1/5] Training Logistic Regression...
#   Trained in 16.0s
#
# [2/5] Training SVM (LinearSVC + Calibration)...
#   Note: C raised from 0.1 to 1.0 to fix majority-class collapse.
#   Trained in 102.3s
#
# [3/5] Training Bernoulli Naive Bayes (with balanced sample weights)...
#   Trained in 0.6s
#
# >>> Evaluating on dev set...
#
# ...
#   Logistic Regression
# ...
#   Accuracy      : 0.5623  (56.23%)
#   Macro F1      : 0.5225
# ...

# %%
# !python "/content/drive/MyDrive/Colab Notebooks/AI PROJECT/src/model_b_train.py"
# Out:
# ...
#   MODEL B - Distractor & Hint Generator Training (IMPROVED)
# ...
#
# >>> Loading data...
#
# >>> Building Distractor Ranker dataset (phrase-level negatives)...
#   Building ranker dataset from 87,866 rows...
#   Dataset: 527,180 examples  |  6 features
#   Class balance: 0.50 positive
#
# [1/3] Training Distractor Ranker (LR + RF)...
#   Dataset shape: (527180, 6)  |  class balance: 0.50 positive
#   Trained in 23.2s
#
#   LR Ranker:
#     Accuracy  : 0.6228
#     Macro F1  : 0.5965
#     Precision : 0.7512
#     Recall    : 0.3673
#               precision    recall  f1-score   support
#
#    Bad Dist.       0.58      0.88      0.70     52716
#   Good Dist.       0.75      0.37      0.49     52720
#
#     accuracy                           0.62    105436
#    macro avg       0.67      0.62      0.60    105436
# weighted avg       0.67      0.62      0.60    105436
#
#
#   RF Ranker:
#     Accuracy  : 0.7780
#     Macro F1  : 0.7727
#     Precision : 0.9011
#     Recall    : 0.6246
# ...
